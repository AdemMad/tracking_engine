# %%
import polars as pl

df = pl.read_parquet(
    r"C:\Users\adamm\Downloads\tracking_files\tracking\tracking_compacted_batch_001.parquet"
)
df
# Out:
# shape: (13_508_022, 24)
# ┌─────────────┬──────┬────────┬──────────┬───┬─────────────┬─────────────┬────────────┬────────────┐
# │ opta_match_ ┆ team ┆ period ┆ frame_id ┆ … ┆ ball_zone   ┆ frame_bucke ┆ player_bal ┆ has_ball_p │
# │ id          ┆ ---  ┆ ---    ┆ ---      ┆   ┆ ---         ┆ t           ┆ l_distance ┆ ossession  │
# │ ---         ┆ cat  ┆ i8     ┆ i32      ┆   ┆ cat         ┆ ---         ┆ ---        ┆ ---        │
# │ i64         ┆      ┆        ┆          ┆   ┆             ┆ i32         ┆ f32        ┆ bool       │
# ╞═════════════╪══════╪════════╪══════════╪═══╪═════════════╪═════════════╪════════════╪════════════╡
# │ 2562179     ┆ away ┆ 1      ┆ 415      ┆ … ┆ att_wide_le ┆ 0           ┆ 18.589422  ┆ false      │
# │             ┆      ┆        ┆          ┆   ┆ ft          ┆             ┆            ┆            │
# │ 2562179     ┆ away ┆ 1      ┆ 416      ┆ … ┆ att_wide_le ┆ 0           ┆ 18.610691  ┆ false      │
# ...
